# %% [markdown]
# ### Extract Knives

# %%
import os
import cv2

image_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/Heavy Weapon Dataset.v1i.yolov11/train/images"
label_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/Heavy Weapon Dataset.v1i.yolov11/train/labels"
output_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/HeavyWeapons_cropped"

os.makedirs(output_dir, exist_ok=True)

for label_filename in os.listdir(label_dir):
    if not label_filename.endswith(".txt"):
        continue
    label_path = os.path.join(label_dir, label_filename)
    image_name = os.path.splitext(label_filename)[0] + ".jpg"
    image_path = os.path.join(image_dir, image_name)

    if not os.path.exists(image_path):
        continue

    image = cv2.imread(image_path)
    height, width = image.shape[:2]

    
    with open(label_path, "r") as file:
        for i, line in enumerate(file):
            parts = line.strip().split()
            if len(parts) != 5:
                continue

            class_id, x_center, y_center, w, h = map(float, parts)

            
            x_center *= width
            y_center *= height
            w *= width
            h *= height

            x1 = int(x_center - w / 2)
            y1 = int(y_center - h / 2)
            x2 = int(x_center + w / 2)
            y2 = int(y_center + h / 2)

            x1 = max(0, x1)
            y1 = max(0, y1)
            x2 = min(width, x2)
            y2 = min(height, y2)

            cropped = image[y1:y2, x1:x2]
            output_filename = f"{os.path.splitext(image_name)[0]}_weapon_{i}.jpg"
            output_path = os.path.join(output_dir, output_filename)
            cv2.imwrite(output_path, cropped)

print("Done. Cropped knife images saved to 'HeavyWeapons' folder.")
# Out:
# Done. Cropped knife images saved to 'HeavyWeapons' folder.

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# #### Histogram of Oriented Gradients (HOG)

# %%
import os
import pandas as pd

data = []
for label, folder in [(1, '/home/group02-f24/Documents/Khalil/CV/Traditional_CV/Weapons'), (0, 'no_weapons')]:
    for fn in os.listdir(folder):
        if fn.lower().endswith(('.jpg','.png','.jpeg')):
            data.append([os.path.join(folder, fn), label])
df = pd.DataFrame(data, columns=['filepath','label'])

# %% [markdown]
# #### Color Histogram

# %%
from skimage.feature import hog
from skimage import io
import numpy as np

TARGET_SIZE = (128, 128)  

def extract_hog(img):
    
    return hog(
        img,
        orientations=9,
        pixels_per_cell=(8,8),
        cells_per_block=(2,2),
        block_norm='L2-Hys',
        feature_vector=True
    )

# %%
import cv2
import numpy as np

def extract_color_hist(img):
    
    img_resized = cv2.resize(img, TARGET_SIZE)
    hsv = cv2.cvtColor(img_resized, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0,1,2], None, (8,8,8),
                        [0,180, 0,256, 0,256])
    cv2.normalize(hist, hist)
    return hist.flatten()

# %% [markdown]
# #### Edge Histogram / Canny + Contour Features

# %%
def extract_edge_ratio(img):
    
    img_resized = cv2.resize(img, TARGET_SIZE)
    edges = cv2.Canny(img_resized, 50,150)
    return np.array([edges.sum() / edges.size])

# %% [markdown]
# #### Combine

# %%
import numpy as np
from skimage import io, color, transform

def extract_features(path):
    gray = io.imread(path, as_gray=True)
    gray = transform.resize(gray, TARGET_SIZE, anti_aliasing=True)
    
    color_img = cv2.imread(path, cv2.IMREAD_COLOR)
    
    f_hog  = extract_hog(gray)
    f_hist = extract_color_hist(color_img)
    f_edge = extract_edge_ratio((gray * 255).astype(np.uint8))
    
    return np.hstack([f_hog, f_hist, f_edge])

# %% [markdown]
# ### Build Your Feature Matrix & Labels

# %%
from tqdm import tqdm

X = []
y = []
for _, row in df.iterrows():
    X.append(extract_features(row.filepath))
    y.append(row.label)

X = np.array(X)
y = np.array(y)

# %% [markdown]
# ###  Train/Test Split & Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test  = scaler.transform(X_test)

# %% [markdown]
# ### Train a Classifier

# %% [markdown]
# #### SVM (not used)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1,1,10],
    'gamma': ['scale','auto'],
    'kernel': ['rbf','linear']
}
svm = GridSearchCV(SVC(probability=True), param_grid, cv=5, verbose= 2, n_jobs=-1)
svm.fit(X_train, y_train)
print("Best SVM params:", svm.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       4 param_grid = {
#       5     'C': [0.1,1,10],
#       6     'gamma': ['scale','auto'],
#       7     'kernel': ['rbf','linear']
#       8 }
#       9 svm = GridSearchCV(SVC(probability=True), param_grid, cv=5, verbose= 2, n_jobs=-1)
# ---> 10 svm.fit(X_train, y_train)
#      11 print("Best SVM params:", svm.best_params_)
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/joblib/parallel.py:2071, in Parallel.__call__(self, iterable)
#    2065 # The first item from the output is blank, but it makes the interpreter
#    2066 # progress until it enters the Try/Except block of the generator and
#    2067 # reaches the first `yield` statement. This starts the asynchronous
#    2068 # dispatch of the tasks to the workers.
#    2069 next(output)
# -> 2071 return output if self.return_generator else list(output)
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/joblib/parallel.py:1681, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1678     yield
#    1680     with self._backend.retrieval_context():
# -> 1681         yield from self._retrieve()
#    1683 except GeneratorExit:
#    1684     # The generator has been garbage collected before being fully
#    1685     # consumed. This aborts the remaining tasks if possible and warn
#    1686     # the user if necessary.
#    1687     self._exception = True
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/joblib/parallel.py:1799, in Parallel._retrieve(self)
#    1788 if self.return_ordered:
#    1789     # Case ordered: wait for completion (or error) of the next job
#    1790     # that have been dispatched and not retrieved yet. If no job
#    (...)   1794     # control only have to be done on the amount of time the next
#    1795     # dispatched job is pending.
#    1796     if (nb_jobs == 0) or (
#    1797         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1798     ):
# -> 1799         time.sleep(0.01)
#    1800         continue
#    1802 elif nb_jobs == 0:
#    1803     # Case unordered: jobs are added to the list of jobs to
#    1804     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1810     # timeouts before any other dispatched job has completed and
#    1811     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# #### XGboost (our model)

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(X_train, label=y_train)
dval   = xgb.DMatrix(X_test,  label=y_test)

params = {
    'objective': 'binary:logistic',
    'eval_metric': 'auc'
}

bst = xgb.train(
    params,
    dtrain,
    num_boost_round=1000,
    early_stopping_rounds=10,
    evals=[(dtrain, 'train'), (dval, 'val')],
    verbose_eval=True
)
# Out:
# [0]	train-auc:0.93373	val-auc:0.88746
# [1]	train-auc:0.95876	val-auc:0.90692
# [2]	train-auc:0.96888	val-auc:0.91895
# [3]	train-auc:0.97518	val-auc:0.92541
# [4]	train-auc:0.97906	val-auc:0.93093
# [5]	train-auc:0.98257	val-auc:0.93808
# [6]	train-auc:0.98549	val-auc:0.94310
# [7]	train-auc:0.98854	val-auc:0.94616
# [8]	train-auc:0.99098	val-auc:0.95051
# [9]	train-auc:0.99309	val-auc:0.95320
# [10]	train-auc:0.99452	val-auc:0.95536
# [11]	train-auc:0.99591	val-auc:0.95724
# [12]	train-auc:0.99684	val-auc:0.95852
# [13]	train-auc:0.99767	val-auc:0.96025
# [14]	train-auc:0.99846	val-auc:0.96199
# [15]	train-auc:0.99881	val-auc:0.96278
# [16]	train-auc:0.99910	val-auc:0.96347
# [17]	train-auc:0.99936	val-auc:0.96451
# [18]	train-auc:0.99950	val-auc:0.96553
# [19]	train-auc:0.99967	val-auc:0.96583
# [20]	train-auc:0.99977	val-auc:0.96724
# [21]	train-auc:0.99985	val-auc:0.96776
# [22]	train-auc:0.99987	val-auc:0.96861
# [23]	train-auc:0.99994	val-auc:0.96908
# [24]	train-auc:0.99997	val-auc:0.96954
# [25]	train-auc:0.99997	val-auc:0.97026
# [26]	train-auc:0.99999	val-auc:0.97057
# [27]	train-auc:0.99999	val-auc:0.97103
# [28]	train-auc:1.00000	val-auc:0.97156
# [29]	train-auc:1.00000	val-auc:0.97210
# [30]	train-auc:1.00000	val-auc:0.97280
# [31]	train-auc:1.00000	val-auc:0.97294
# [32]	train-auc:1.00000	val-auc:0.97310
# [33]	train-auc:1.00000	val-auc:0.97345
# [34]	train-auc:1.00000	val-auc:0.97361
# [35]	train-auc:1.00000	val-auc:0.97378
# [36]	train-auc:1.00000	val-auc:0.97368
# [37]	train-auc:1.00000	val-auc:0.97418
# [38]	train-auc:1.00000	val-auc:0.97442
# [39]	train-auc:1.00000	val-auc:0.97506
# [40]	train-auc:1.00000	val-auc:0.97539
# [41]	train-auc:1.00000	val-auc:0.97576
# [42]	train-auc:1.00000	val-auc:0.97574
# [43]	train-auc:1.00000	val-auc:0.97586
# [44]	train-auc:1.00000	val-auc:0.97605
# [45]	train-auc:1.00000	val-auc:0.97610
# [46]	train-auc:1.00000	val-auc:0.97637
# [47]	train-auc:1.00000	val-auc:0.97665
# [48]	train-auc:1.00000	val-auc:0.97691
# [49]	train-auc:1.00000	val-auc:0.97702
# [50]	train-auc:1.00000	val-auc:0.97723
# [51]	train-auc:1.00000	val-auc:0.97745
# [52]	train-auc:1.00000	val-auc:0.97770
# [53]	train-auc:1.00000	val-auc:0.97776
# [54]	train-auc:1.00000	val-auc:0.97788
# [55]	train-auc:1.00000	val-auc:0.97808
# [56]	train-auc:1.00000	val-auc:0.97831
# [57]	train-auc:1.00000	val-auc:0.97858
# [58]	train-auc:1.00000	val-auc:0.97875
# [59]	train-auc:1.00000	val-auc:0.97883
# [60]	train-auc:1.00000	val-auc:0.97888
# [61]	train-auc:1.00000	val-auc:0.97912
# [62]	train-auc:1.00000	val-auc:0.97936
# [63]	train-auc:1.00000	val-auc:0.97937
# [64]	train-auc:1.00000	val-auc:0.97931
# [65]	train-auc:1.00000	val-auc:0.97940
# [66]	train-auc:1.00000	val-auc:0.97955
# [67]	train-auc:1.00000	val-auc:0.97951
# [68]	train-auc:1.00000	val-auc:0.97969
# [69]	train-auc:1.00000	val-auc:0.97977
# [70]	train-auc:1.00000	val-auc:0.97986
# [71]	train-auc:1.00000	val-auc:0.97995
# [72]	train-auc:1.00000	val-auc:0.97998
# [73]	train-auc:1.00000	val-auc:0.97999
# [74]	train-auc:1.00000	val-auc:0.98020
# [75]	train-auc:1.00000	val-auc:0.98020
# [76]	train-auc:1.00000	val-auc:0.98033
# [77]	train-auc:1.00000	val-auc:0.98052
# [78]	train-auc:1.00000	val-auc:0.98052
# [79]	train-auc:1.00000	val-auc:0.98056
# [80]	train-auc:1.00000	val-auc:0.98064
# [81]	train-auc:1.00000	val-auc:0.98063
# [82]	train-auc:1.00000	val-auc:0.98067
# [83]	train-auc:1.00000	val-auc:0.98077
# [84]	train-auc:1.00000	val-auc:0.98072
# [85]	train-auc:1.00000	val-auc:0.98074
# [86]	train-auc:1.00000	val-auc:0.98103
# [87]	train-auc:1.00000	val-auc:0.98106
# [88]	train-auc:1.00000	val-auc:0.98102
# [89]	train-auc:1.00000	val-auc:0.98105
# [90]	train-auc:1.00000	val-auc:0.98110
# [91]	train-auc:1.00000	val-auc:0.98110
# [92]	train-auc:1.00000	val-auc:0.98120
# [93]	train-auc:1.00000	val-auc:0.98114
# [94]	train-auc:1.00000	val-auc:0.98128
# [95]	train-auc:1.00000	val-auc:0.98128
# [96]	train-auc:1.00000	val-auc:0.98124
# [97]	train-auc:1.00000	val-auc:0.98130
# [98]	train-auc:1.00000	val-auc:0.98138
# [99]	train-auc:1.00000	val-auc:0.98142
# [100]	train-auc:1.00000	val-auc:0.98143
# [101]	train-auc:1.00000	val-auc:0.98147
# [102]	train-auc:1.00000	val-auc:0.98147
# [103]	train-auc:1.00000	val-auc:0.98152
# [104]	train-auc:1.00000	val-auc:0.98159
# [105]	train-auc:1.00000	val-auc:0.98159
# [106]	train-auc:1.00000	val-auc:0.98158
# [107]	train-auc:1.00000	val-auc:0.98165
# [108]	train-auc:1.00000	val-auc:0.98160
# [109]	train-auc:1.00000	val-auc:0.98168
# [110]	train-auc:1.00000	val-auc:0.98170
# [111]	train-auc:1.00000	val-auc:0.98173
# [112]	train-auc:1.00000	val-auc:0.98178
# [113]	train-auc:1.00000	val-auc:0.98179
# [114]	train-auc:1.00000	val-auc:0.98189
# [115]	train-auc:1.00000	val-auc:0.98191
# [116]	train-auc:1.00000	val-auc:0.98194
# [117]	train-auc:1.00000	val-auc:0.98201
# [118]	train-auc:1.00000	val-auc:0.98201
# [119]	train-auc:1.00000	val-auc:0.98204
# [120]	train-auc:1.00000	val-auc:0.98204
# [121]	train-auc:1.00000	val-auc:0.98215
# [122]	train-auc:1.00000	val-auc:0.98214
# [123]	train-auc:1.00000	val-auc:0.98217
# [124]	train-auc:1.00000	val-auc:0.98217
# [125]	train-auc:1.00000	val-auc:0.98220
# [126]	train-auc:1.00000	val-auc:0.98228
# [127]	train-auc:1.00000	val-auc:0.98234
# [128]	train-auc:1.00000	val-auc:0.98234
# [129]	train-auc:1.00000	val-auc:0.98229
# [130]	train-auc:1.00000	val-auc:0.98223
# [131]	train-auc:1.00000	val-auc:0.98228
# [132]	train-auc:1.00000	val-auc:0.98227
# [133]	train-auc:1.00000	val-auc:0.98231
# [134]	train-auc:1.00000	val-auc:0.98233
# [135]	train-auc:1.00000	val-auc:0.98237
# [136]	train-auc:1.00000	val-auc:0.98240
# [137]	train-auc:1.00000	val-auc:0.98238
# [138]	train-auc:1.00000	val-auc:0.98230
# [139]	train-auc:1.00000	val-auc:0.98236
# [140]	train-auc:1.00000	val-auc:0.98239
# [141]	train-auc:1.00000	val-auc:0.98245
# [142]	train-auc:1.00000	val-auc:0.98243
# [143]	train-auc:1.00000	val-auc:0.98245
# [144]	train-auc:1.00000	val-auc:0.98246
# [145]	train-auc:1.00000	val-auc:0.98246
# [146]	train-auc:1.00000	val-auc:0.98249
# [147]	train-auc:1.00000	val-auc:0.98246
# [148]	train-auc:1.00000	val-auc:0.98247
# [149]	train-auc:1.00000	val-auc:0.98248
# [150]	train-auc:1.00000	val-auc:0.98245
# [151]	train-auc:1.00000	val-auc:0.98246
# [152]	train-auc:1.00000	val-auc:0.98250
# [153]	train-auc:1.00000	val-auc:0.98250
# [154]	train-auc:1.00000	val-auc:0.98248
# [155]	train-auc:1.00000	val-auc:0.98246
# [156]	train-auc:1.00000	val-auc:0.98245
# [157]	train-auc:1.00000	val-auc:0.98245
# [158]	train-auc:1.00000	val-auc:0.98250
# [159]	train-auc:1.00000	val-auc:0.98248
# [160]	train-auc:1.00000	val-auc:0.98253
# [161]	train-auc:1.00000	val-auc:0.98253
# [162]	train-auc:1.00000	val-auc:0.98256
# [163]	train-auc:1.00000	val-auc:0.98258
# [164]	train-auc:1.00000	val-auc:0.98251
# [165]	train-auc:1.00000	val-auc:0.98254
# [166]	train-auc:1.00000	val-auc:0.98258
# [167]	train-auc:1.00000	val-auc:0.98262
# [168]	train-auc:1.00000	val-auc:0.98259
# [169]	train-auc:1.00000	val-auc:0.98259
# [170]	train-auc:1.00000	val-auc:0.98260
# [171]	train-auc:1.00000	val-auc:0.98260
# [172]	train-auc:1.00000	val-auc:0.98266
# [173]	train-auc:1.00000	val-auc:0.98269
# [174]	train-auc:1.00000	val-auc:0.98273
# [175]	train-auc:1.00000	val-auc:0.98270
# [176]	train-auc:1.00000	val-auc:0.98268
# [177]	train-auc:1.00000	val-auc:0.98267
# [178]	train-auc:1.00000	val-auc:0.98269
# [179]	train-auc:1.00000	val-auc:0.98269
# [180]	train-auc:1.00000	val-auc:0.98268
# [181]	train-auc:1.00000	val-auc:0.98265
# [182]	train-auc:1.00000	val-auc:0.98267
# [183]	train-auc:1.00000	val-auc:0.98270

# %% [markdown]
# ### Evaluate

# %%
from sklearn.metrics import classification_report, roc_auc_score


import xgboost as xgb
dtest      = xgb.DMatrix(X_test)
y_prob_xgb = bst.predict(dtest)
y_pred_xgb = (y_prob_xgb > 0.5).astype(int)

print("--- XGBoost (Booster) ---")
print(classification_report(y_test, y_pred_xgb))
print("ROC AUC:", roc_auc_score(y_test, y_prob_xgb))
# Out:
# --- XGBoost (Booster) ---
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      1200
#            1       0.92      0.95      0.93      1200
#
#     accuracy                           0.93      2400
#    macro avg       0.93      0.93      0.93      2400
# weighted avg       0.93      0.93      0.93      2400
#
# ROC AUC: 0.9827159722222222

# %%
bst = xgb.Booster()
bst.load_model('weapon_booster.model')

# %% [markdown]
# #### predict function (to run on some test cases)

# %%
import cv2
import numpy as np
import xgboost as xgb  
from skimage.feature import hog
from skimage import io, transform

TARGET_SIZE = (128,128)

def extract_features(path):
    gray = io.imread(path, as_gray=True)
    gray = transform.resize(gray, TARGET_SIZE, anti_aliasing=True)
    
    hog_vec = hog(
        gray,
        orientations=9,
        pixels_per_cell=(8,8),
        cells_per_block=(2,2),
        block_norm='L2-Hys',
        feature_vector=True
    )
    
    color_img = cv2.imread(path, cv2.IMREAD_COLOR)
    color_resized = cv2.resize(color_img, TARGET_SIZE)
    hsv = cv2.cvtColor(color_resized, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0,1,2], None, (8,8,8),
                        [0,180,0,256,0,256]).flatten()
    cv2.normalize(hist, hist)
    
    edges = cv2.Canny((gray*255).astype(np.uint8), 50,150)
    edge_ratio = np.array([edges.sum()/edges.size])
    
    return np.hstack([hog_vec, hist, edge_ratio])


def predict_image(path, model, scaler=None, booster=bst, threshold=0.5):
    
    feats = extract_features(path).reshape(1, -1)
    
    if scaler is not None:
        feats = scaler.transform(feats)

    if booster is not None:
        
        dmat = xgb.DMatrix(feats)
        prob = booster.predict(dmat)[0]
        pred = int(prob > threshold)
    else:
        
        prob = model.predict_proba(feats)[0,1]
        pred = model.predict(feats)[0]

    label = "weapon" if pred==1 else "no_weapon"
    print(f"Prediction: {label} (p={prob:.3f})")
    return pred, prob


path = '/home/group02-f24/Documents/Khalil/CV/Traditional_CV/input_for_yolo_with_x/pexels-specna-arms-306304-886453.jpg'

pred, prob = predict_image(path, model=None, scaler=scaler, booster=bst)
# Out:
# Prediction: no_weapon (p=0.240)

# %% [markdown]
# #### cropping the gun photos

# %%
import os
import json
from PIL import Image

images_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/Guns/ds/img"
json_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/Guns/ds/ann"
output_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/Guns_cropped"

os.makedirs(output_dir, exist_ok=True)

def crop_image(image_path, json_path, output_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    
    img = Image.open(image_path)
    
    obj = data['objects'][0]
    exterior = obj['points']['exterior']
    
    left = int(exterior[0][0])
    upper = int(exterior[0][1])
    right = int(exterior[1][0])
    lower = int(exterior[1][1])
    
    cropped_img = img.crop((left, upper, right, lower))
    cropped_img.save(output_path)

for filename in os.listdir(images_dir):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(images_dir, filename)
        
        json_filename = filename + '.json'
        json_path = os.path.join(json_dir, json_filename)
        
        if os.path.exists(json_path):
            output_path = os.path.join(output_dir, filename)
            crop_image(image_path, json_path, output_path)
            print(f"Cropped and saved {filename}")
        else:
            print(f"JSON file not found for {filename}")
# Out:
# Cropped and saved armas (554).jpg
# Cropped and saved armas (385).jpg
# Cropped and saved armas (2120).jpg
# Cropped and saved armas (2490).jpg
# Cropped and saved armas (2723).jpg
# Cropped and saved armas (1380).jpg
# Cropped and saved armas (665).jpg
# Cropped and saved armas (2970).jpg
# Cropped and saved armas (2522).jpg
# Cropped and saved armas (2672).jpg
# Cropped and saved armas (1404).jpg
# Cropped and saved armas (634).jpg
# Cropped and saved armas (2674).jpg
# Cropped and saved armas (2400).jpg
# Cropped and saved armas (463).jpg
# Cropped and saved armas (2170).jpg
# Cropped and saved armas (2991).jpg
# Cropped and saved armas (2457).jpg
# Cropped and saved armas (1962).jpg
# Cropped and saved armas (1363).jpg
# Cropped and saved armas (1637).jpg
# Cropped and saved armas (2280).jpg
# Cropped and saved armas (1155).jpg
# Cropped and saved armas (719).jpg
# Cropped and saved armas (1005).jpg
# Cropped and saved armas (157).jpg
# Cropped and saved armas (2488).jpg
# Cropped and saved armas (987).jpg
# Cropped and saved armas (1646).jpg
# Cropped and saved armas (1681).jpg
# Cropped and saved armas (390).jpg
# Cropped and saved armas (2590).jpg
# Cropped and saved armas (2333).jpg
# Cropped and saved armas (835).jpg
# Cropped and saved armas (426).jpg
# Cropped and saved armas (559).jpg
# Cropped and saved armas (1259).jpg
# Cropped and saved armas (1087).jpg
# Cropped and saved armas (805).jpg
# Cropped and saved armas (1128).jpg
# Cropped and saved armas (2046).jpg
# Cropped and saved armas (1286).jpg
# Cropped and saved armas (41).jpg
# Cropped and saved armas (2624).jpg
# Cropped and saved armas (272).jpg
# Cropped and saved armas (204).jpg
# Cropped and saved armas (1170).jpg
# Cropped and saved armas (2621).jpg
# Cropped and saved armas (887).jpg
# Cropped and saved armas (2863).jpg
# Cropped and saved armas (287).jpg
# Cropped and saved armas (1339).jpg
# Cropped and saved armas (1741).jpg
# Cropped and saved armas (598).jpg
# Cropped and saved armas (317).jpg
# Cropped and saved armas (943).jpg
# Cropped and saved armas (1571).jpg
# Cropped and saved armas (776).jpg
# Cropped and saved armas (1142).jpg
# Cropped and saved armas (1433).jpg
# Cropped and saved armas (2031).jpg
# Cropped and saved armas (1126).jpg
# Cropped and saved armas (1753).jpg
# Cropped and saved armas (1057).jpg
# Cropped and saved armas (934).jpg
# Cropped and saved armas (1751).jpg
# Cropped and saved armas (534).jpg
# Cropped and saved armas (1736).jpg
# Cropped and saved armas (1759).jpg
# Cropped and saved armas (2870).jpg
# Cropped and saved armas (531).jpg
# Cropped and saved armas (2040).jpg
# Cropped and saved armas (1657).jpg
# Cropped and saved armas (1260).jpg
# Cropped and saved armas (2586).jpg
# Cropped and saved armas (1432).jpg
# Cropped and saved armas (2541).jpg
# Cropped and saved armas (886).jpg
# Cropped and saved armas (1558).jpg
# Cropped and saved armas (2082).jpg
# Cropped and saved armas (1134).jpg
# Cropped and saved armas (2907).jpg
# Cropped and saved armas (1893).jpg
# Cropped and saved armas (2743).jpg
# Cropped and saved armas (1888).jpg
# Cropped and saved armas (1861).jpg
# Cropped and saved armas (1318).jpg
# Cropped and saved armas (2609).jpg
# Cropped and saved armas (587).jpg
# Cropped and saved armas (482).jpg
# Cropped and saved armas (2525).jpg
# Cropped and saved armas (2497).jpg
# Cropped and saved armas (694).jpg
# Cropped and saved armas (2163).jpg
# Cropped and saved armas (2641).jpg
# Cropped and saved armas (728).jpg
# Cropped and saved armas (2901).jpg
# Cropped and saved armas (1641).jpg
# Cropped and saved armas (827).jpg
# Cropped and saved armas (2814).jpg
# Cropped and saved armas (1011).jpg
# Cropped and saved armas (483).jpg
# Cropped and saved armas (1050).jpg
# Cropped and saved armas (600).jpg
# Cropped and saved armas (2764).jpg
# Cropped and saved armas (524).jpg
# Cropped and saved armas (1774).jpg
# Cropped and saved armas (1801).jpg
# Cropped and saved armas (1360).jpg
# Cropped and saved armas (1007).jpg

# %% [markdown]
# #### preparing the data (2000 knife 2000 gun 2000 heavy weapon 6000 non)

# %%
import os
import random
import shutil

def copy_random_images_append(src_folder, dst_folder, num_images=6000):
    os.makedirs(dst_folder, exist_ok=True)

    valid_exts = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff'}
    all_images = [f for f in os.listdir(src_folder)
                  if os.path.splitext(f)[1].lower() in valid_exts]

    if len(all_images) < num_images:
        print(f"Warning: only found {len(all_images)} images, less than {num_images} requested.")
        num_images = len(all_images)

    selected_images = random.sample(all_images, num_images)

    for img_name in selected_images:
        src_path = os.path.join(src_folder, img_name)

        dst_path = os.path.join(dst_folder, img_name)

        base, ext = os.path.splitext(img_name)
        count = 1
        while os.path.exists(dst_path):
            dst_path = os.path.join(dst_folder, f"{base}_{count}{ext}")
            count += 1

        shutil.copy2(src_path, dst_path)

    print(f"Appended {num_images} images from {src_folder} to {dst_folder}.")

source_folder = "/home/group02-f24/Documents/Khalil/CV/negative_images/images"
destination_folder = "no_weapons"
copy_random_images_append(source_folder, destination_folder, 6000)
# Out:
# Appended 6000 images from /home/group02-f24/Documents/Khalil/CV/negative_images/images to no_weapons.

# %% [markdown]
# ### Evaluate on YOLO validation set

# %%
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np


valid_images_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/weapon-detection.v16-remapped-train-80-val-20.yolov11/valid/images"
valid_labels_dir = "/home/group02-f24/Documents/Khalil/CV/Traditional_CV/weapon-detection.v16-remapped-train-80-val-20.yolov11/valid/labels"

true_labels = []
pred_labels = []

image_files = [f for f in os.listdir(valid_images_dir) if f.lower().endswith(('.jpg','.png','.jpeg'))]

for img_file in image_files:
    img_path = os.path.join(valid_images_dir, img_file)
    label_file = os.path.splitext(img_file)[0] + ".txt"
    label_path = os.path.join(valid_labels_dir, label_file)

    gt = 0
    if os.path.exists(label_path):
        with open(label_path, 'r') as lf:
            lines = lf.readlines()
            for line in lines:
                if line.strip().startswith('0'):
                    gt = 1
                    break

    pred, prob = predict_image(img_path, model=None, scaler=scaler, booster=bst, threshold=0.5)

    true_labels.append(gt)
    pred_labels.append(pred)

acc = accuracy_score(true_labels, pred_labels)
prec = precision_score(true_labels, pred_labels)
rec = recall_score(true_labels, pred_labels)
f1 = f1_score(true_labels, pred_labels)

print(f"Validation Results:\nAccuracy: {acc:.4f}\nPrecision: {prec:.4f}\nRecall: {rec:.4f}\nF1 Score: {f1:.4f}")
# Out:
# Prediction: weapon (p=0.986)
# Prediction: weapon (p=0.994)
# Prediction: no_weapon (p=0.162)
# Prediction: weapon (p=0.623)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.846)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.988)
# Prediction: no_weapon (p=0.020)
# Prediction: no_weapon (p=0.002)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.093)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.006)
# Prediction: weapon (p=0.996)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.447)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.999)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.738)
# Prediction: no_weapon (p=0.002)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.001)
# Prediction: weapon (p=0.997)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.003)
# Prediction: no_weapon (p=0.027)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.644)
# Prediction: weapon (p=0.986)
# Prediction: weapon (p=0.998)
# Prediction: no_weapon (p=0.454)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.741)
# Prediction: no_weapon (p=0.019)
# Prediction: weapon (p=0.999)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.144)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.008)
# Prediction: weapon (p=0.999)
# Prediction: weapon (p=0.993)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.981)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.032)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.937)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.911)
# Prediction: weapon (p=0.970)
# Prediction: no_weapon (p=0.038)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.988)
# Prediction: weapon (p=0.822)
# Prediction: weapon (p=0.733)
# Prediction: no_weapon (p=0.117)
# Prediction: no_weapon (p=0.015)
# Prediction: weapon (p=0.996)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.038)
# Prediction: weapon (p=0.999)
# Prediction: weapon (p=0.998)
# Prediction: weapon (p=0.616)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.081)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.579)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.999)
# Prediction: weapon (p=0.992)
# Prediction: weapon (p=0.849)
# Prediction: no_weapon (p=0.224)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.888)
# Prediction: weapon (p=0.946)
# Prediction: no_weapon (p=0.040)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.033)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.004)
# Prediction: weapon (p=0.898)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.759)
# Prediction: weapon (p=0.987)
# Prediction: no_weapon (p=0.013)
# Prediction: weapon (p=0.999)
# Prediction: no_weapon (p=0.351)
# Prediction: no_weapon (p=0.001)
# Prediction: weapon (p=0.990)
# Prediction: weapon (p=0.657)
# Prediction: no_weapon (p=0.002)
# Prediction: no_weapon (p=0.339)
# Prediction: no_weapon (p=0.087)
# Prediction: weapon (p=0.878)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.998)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.019)
# Prediction: weapon (p=0.999)
# Prediction: no_weapon (p=0.202)
# Prediction: weapon (p=0.980)
# Prediction: no_weapon (p=0.163)
# Prediction: no_weapon (p=0.455)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.919)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.011)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.004)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.996)
# Prediction: no_weapon (p=0.330)
# Prediction: weapon (p=0.999)
# Prediction: weapon (p=0.738)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.907)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.997)
# Prediction: weapon (p=0.969)
# Prediction: no_weapon (p=0.293)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.343)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.836)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.002)
# Prediction: no_weapon (p=0.007)
# Prediction: weapon (p=0.698)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.999)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.992)
# Prediction: no_weapon (p=0.448)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.187)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.980)
# Prediction: weapon (p=0.957)
# Prediction: no_weapon (p=0.009)
# Prediction: weapon (p=0.849)
# Prediction: no_weapon (p=0.023)
# Prediction: weapon (p=0.998)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.001)
# Prediction: no_weapon (p=0.008)
# Prediction: weapon (p=0.860)
# Prediction: no_weapon (p=0.170)
# Prediction: no_weapon (p=0.001)
# Prediction: no_weapon (p=0.002)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.069)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.967)
# Prediction: no_weapon (p=0.002)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.002)
# Prediction: no_weapon (p=0.065)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.350)
# Prediction: weapon (p=0.996)
# Prediction: weapon (p=0.951)
# Prediction: weapon (p=0.854)
# Prediction: weapon (p=0.929)
# Prediction: weapon (p=0.999)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.993)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.697)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=0.989)
# Prediction: weapon (p=0.999)
# Prediction: no_weapon (p=0.380)
# Prediction: weapon (p=0.778)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.539)
# Prediction: weapon (p=0.878)
# Prediction: weapon (p=0.600)
# Prediction: weapon (p=0.989)
# Prediction: weapon (p=0.925)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.167)
# Prediction: weapon (p=0.989)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.020)
# Prediction: weapon (p=0.982)
# Prediction: weapon (p=0.698)
# Prediction: weapon (p=0.840)
# Prediction: no_weapon (p=0.123)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.992)
# Prediction: weapon (p=1.000)
# Prediction: weapon (p=1.000)
# Prediction: no_weapon (p=0.051)
# Prediction: weapon (p=0.855)
# Prediction: weapon (p=0.962)
# Prediction: weapon (p=0.996)
# Prediction: weapon (p=0.839)
# Prediction: no_weapon (p=0.000)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=0.951)
# Prediction: no_weapon (p=0.163)
# Prediction: weapon (p=0.873)
# Prediction: weapon (p=0.666)
# Prediction: no_weapon (p=0.015)
# Prediction: no_weapon (p=0.000)
# Prediction: weapon (p=1.000)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 31
#      28                 break
#      30 # Prediction
# ---> 31 pred, prob = predict_image(img_path, model=None, scaler=scaler, booster=bst, threshold=0.5)
#      33 true_labels.append(gt)
#      34 pred_labels.append(pred)
#
# Cell In[10], line 53, in predict_image(path, model, scaler, booster, threshold)
#      49     feats = scaler.transform(feats)
#      51 if booster is not None:
#      52     # low-level API
# ---> 53     dmat = xgb.DMatrix(feats)
#      54     prob = booster.predict(dmat)[0]
#      55     pred = int(prob > threshold)
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/xgboost/core.py:885, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#     882     assert self.handle is not None
#     883     return
# --> 885 handle, feature_names, feature_types = dispatch_data_backend(
#     886     data=data,
#     887     missing=self.missing,
#     888     threads=self.nthread,
#     889     feature_names=feature_names,
#     890     feature_types=feature_types,
#     891     enable_categorical=enable_categorical,
#     892     data_split_mode=data_split_mode,
#     893 )
#     894 assert handle is not None
#     895 self.handle = handle
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/xgboost/data.py:1382, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical, data_split_mode)
#    1373     return _from_scipy_csr(
#    1374         data=data.tocsr(),
#    1375         missing=missing,
#    (...)   1379         data_split_mode=data_split_mode,
#    1380     )
#    1381 if _is_np_array_like(data):
# -> 1382     return _from_numpy_array(
#    1383         data=data,
#    1384         missing=missing,
#    1385         nthread=threads,
#    1386         feature_names=feature_names,
#    1387         feature_types=feature_types,
#    1388         data_split_mode=data_split_mode,
#    1389     )
#    1390 if _is_uri(data):
#    1391     return _from_uri(data, missing, feature_names, feature_types, data_split_mode)
#
# File ~/anaconda3/envs/cvenv/lib/python3.12/site-packages/xgboost/data.py:272, in _from_numpy_array(data, missing, nthread, feature_names, feature_types, data_split_mode)
#     269 data, _ = _ensure_np_dtype(data, data.dtype)
#     270 handle = ctypes.c_void_p()
#     271 _check_call(
# --> 272     _LIB.XGDMatrixCreateFromDense(
#     273         array_interface(data),
#     274         make_jcargs(
#     275             missing=float(missing),
#     276             nthread=int(nthread),
#     277             data_split_mode=int(data_split_mode),
#     278         ),
#     279         ctypes.byref(handle),
#     280     )
#     281 )
#     282 return handle, feature_names, feature_types
#
# KeyboardInterrupt:

# %% [markdown]
# ### YOLO + Traditional CV (complete pipeline )

# %%
import os
from pathlib import Path
from PIL import Image, ImageDraw
from ultralytics import YOLO
import cv2
import numpy as np
from skimage.feature import hog
from skimage import io, transform

# loud yolo

yolo = YOLO('/home/group02-f24/Documents/Khalil/CV/ultralytics/yolo11x.pt')

booster = bst
 
def process_folder(image_folder, output_folder, crop_folder):
    os.makedirs(output_folder, exist_ok=True)
    os.makedirs(crop_folder, exist_ok=True)

    for img_path in Path(image_folder).glob('*.*'):
        if img_path.suffix.lower() not in {'.jpg','.jpeg','.png','.bmp'}:
            continue

        pil_img = Image.open(img_path).convert('RGB')
        draw   = ImageDraw.Draw(pil_img)

        # detect objects
        results = yolo.predict(source=str(img_path), conf=0.3)

        for i, box in enumerate(results[0].boxes):
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
            crop = pil_img.crop((x1, y1, x2, y2))

            # save crop permanently
            crop_name = f"{img_path.stem}_crop_{i}.jpg"
            crop_path = Path(crop_folder) / crop_name
            crop.save(crop_path)

            #  prediction
            pred, prob = predict_image(
                str(crop_path),
                model=None,
                scaler=scaler,
                booster=booster
            )

            # annotate original if weapon
            if pred == 1:
                draw.rectangle([x1, y1, x2, y2], outline='red', width=3)
                draw.text((x1, y1-10), f"{prob:.2f}", fill='red')

        # save annotated image
        out_path = Path(output_folder) / img_path.name
        pil_img.save(out_path)
        print(f"Processed {img_path.name}, crops saved to {crop_folder}")

if __name__ == '__main__':
    process_folder(
        image_folder  = '/home/group02-f24/Documents/Khalil/CV/Traditional_CV/input_for_yolo_with_x',
        output_folder = '/home/group02-f24/Documents/Khalil/CV/Traditional_CV/results',
        crop_folder   = '/home/group02-f24/Documents/Khalil/CV/Traditional_CV/crops'
    )
# Out:
# image 1/1 /home/group02-f24/Documents/Khalil/CV/Traditional_CV/input_for_yolo_with_x/pexels-specna-arms-306304-886453.jpg: 448x640 1 person, 1 motorcycle, 12.9ms
# Speed: 1.7ms preprocess, 12.9ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# Prediction: weapon (p=0.700)
# Prediction: weapon (p=0.999)
# Processed pexels-specna-arms-306304-886453.jpg, crops saved to /home/group02-f24/Documents/Khalil/CV/Traditional_CV/crops
